# %% [markdown]
# # Data Setup

# %% [markdown]
# # Define Charts

# %% [markdown]
# ## Chart 1: Who is Building the Brains? (Horizontal Bar)

# %% [markdown]
# ## Chart 2: The Exponential Cost (Diverging Bar)

# %% [markdown]
# ## Chart 3: The Physical Footprint (Geospatial Map)

# %% [markdown]
# ## Chart 4: Carbon-Compute Matrix

# %% [markdown]
# # Global Sidebar Controls

# %% [markdown]
# # Custom JS Callbacks

# %% [markdown]
# # Layout and Output
