# %%
import requests

# %% [markdown]
# # All countries

# %%
response_all = requests.get("https://aidatacenterindex.com/api/countries.json")

# %%
response_all.json()
# Out:
# {'generated_at': '2026-05-23T04:29:44.736Z',
#  'total_countries': 64,
#  'total_facilities': 344,
#  'note': 'Country-level aggregation of AI data center facilities. For individual facility data, see /api/facilities.json or request bulk access at https://aidatacenterindex.com/data/',
#  'countries': [{'name': 'United States',
#    'slug': 'united-states',
#    'url': 'https://aidatacenterindex.com/countries/united-states/',
#    'facilities': 84,
#    'megawatts': 70572,
#    'status': {'operational': 46,
#     'under_construction': 16,
#     'planned': 13,
#     'announced': 9},
#    'operator_count': 46,
#    'top_operators': ['Amazon Web Services',
#     'Talen Energy',
#     'Apple',
#     'Applied Digital',
#     'Atlas Development & Prologis']},
#   {'name': 'India',
#    'slug': 'india',
#    'url': 'https://aidatacenterindex.com/countries/india/',
#    'facilities': 11,
#    'megawatts': 3130,
#    'status': {'operational': 5,
#     'under_construction': 2,
# ...

# %%
[item["slug"] for item in response_all.json()["countries"]]
# Out:
# ['united-states',
#  'india',
#  'germany',
#  'south-korea',
#  'japan',
#  'united-kingdom',
#  'france',
#  'united-arab-emirates',
#  'australia',
#  'singapore',
#  'saudi-arabia',
#  'canada',
#  'china',
#  'south-africa',
#  'malaysia',
#  'thailand',
#  'spain',
#  'brazil',
#  'ireland',
#  'indonesia',
#  'israel',
#  'taiwan',
#  'norway',
#  'finland',
#  'mexico',
#  'new-zealand',
#  'sweden',
#  'nigeria',
#  'netherlands',
#  'turkey',
#  'italy',
#  'vietnam',
#  'qatar',
#  'egypt',
#  'chile',
#  'philippines',
#  'colombia',
#  'denmark',
#  'kuwait',
#  'russia',
#  'bahrain',
#  'hong-kong',
#  'switzerland',
#  'morocco',
#  'argentina',
#  'belgium',
#  'austria',
#  'poland',
#  'portugal',
#  'romania',
#  'greece',
#  'jordan',
#  'iceland',
#  'peru',
#  'uzbekistan',
#  'bulgaria',
#  'kazakhstan',
#  'ethiopia',
#  'armenia',
#  'luxembourg',
#  'czech-republic',
#  'kenya',
#  'oman',
#  'tanzania']

# %% [markdown]
# # Per country

# %%
response_country = requests.get("https://aidatacenterindex.com/countries/czech-republic/index.json")

# %%
response_country.json()
# Out:
# {'generated_at': '2026-05-23T04:29:53.011Z',
#  'license': 'CC BY 4.0',
#  'taxonomy': {'type': 'country',
#   'name': 'Czech Republic',
#   'slug': 'czech-republic',
#   'item_count': 1,
#   'total_megawatts': 50},
#  'items': [{'id': 'microsoft-azure-czech-republic-prague',
#    'title': 'Microsoft Azure — Czech Republic Region (Prague)',
#    'url': 'https://aidatacenterindex.com/datacenters/microsoft-azure-czech-republic-prague.html',
#    'megawatts': 50,
#    'companies': ['Microsoft'],
#    'country': 'Czech Republic',
#    'region': 'Prague',
#    'city': 'Prague',
#    'status': 'announced',
#    'energy_type': 'Mixed',
#    'ai_focus': 'Inference (Azure AI, Central European data residency)',
#    'start_year': 2026,
#    'lat': 50.075,
#    'lng': 14.437,
#    'sources': ['https://news.microsoft.com/europe/2024/05/22/microsoft-announces-investment-in-czechia/',
#     'https://azure.microsoft.com/en-us/explore/global-infrastructure/geographies/']}]}
